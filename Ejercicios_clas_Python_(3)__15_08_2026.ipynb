# %% [markdown]
# #**Ejercicios de práctica Fundamentos Python (3)**
# ###Ejercicios práctica funciones

# %% [markdown]
# ##**A. Definir y llamar**

# %% [markdown]
# #### 1.  Definir una función
#
# ##### *Complete la palabra clave que define una función.*

# %%
def saludar():
  print("Hola")

saludar()
# Out:
# Hola

# %% [markdown]
# #### 2.   Llamar a la función
#
# ##### *Complete la línea que ejecuta la función ya definida*

# %%
def bienvenida():
  print("Bienvenido al curso")

bienvenida()
# Out:
# Bienvenido al curso

# %% [markdown]
# #### 3. Predice el orden de ejecución
#
# ##### *Ejercicios práctica funciones*

# %%
def uno():
  print("A")

print("B")
uno()
print("C")
# Out:
# B
# A
# C

# %% [markdown]
# #### 4. Corrige el orden
#
# ##### *El programa falla porque la función se llama antes de existir. Reescriba las líneas en el orden correcto.*

# %%
def saludar(nombre):
  print("Hola",nombre)

saludar("Ana")
# Out:
# Hola Ana

# %% [markdown]
# #### 5. Función con un parámetro
#
# ##### *Complete el parámetro que recibe la función.*

# %%
def saludar(nombre):
  print("Hola", nombre)

saludar("Ana")
# Out:
# Hola Ana

# %% [markdown]
# #### 6. Reutilizar la misma función
#
# ##### *Llame tres veces a la misma función, cada vez con un precio distinto.*

# %%
def con_iva(precio):
  return precio * 1.19

print(con_iva(5000))
print(con_iva(10000))
print(con_iva(20000))
# Out:
# 5950.0
# 11900.0
# 23800.0

# %% [markdown]
# ##**B. Parámetros y argumentos**

# %% [markdown]
# #### 7. Función con dos parámetros
#
# ##### *Complete los dos parámetros que la función necesita.*

# %%
def area(base,altura):
  return base*altura

print(area(3,4))
# Out:
# 12

# %% [markdown]
# #### 8.  Completa la llamada
#
# ##### *Complete los argumentos para obtener exactamente el resultado indicado*

# %%
def area(base,altura):
  return base * altura

print(area(5.0,5.0))
# Out:
# 25.0

# %% [markdown]
# #### 9.  Parámetro o argumento
#
# ##### *Observe la definición y la llamada, y distinga cada uno de los dos nombres.*

# %%
def doble(n):
  return n*2

resultado = doble (5)
print(resultado)
# Out:
# 10

# %% [markdown]
# #### **Respuesta:**
# #####-El parametro en este ejercicio corresponde a n ya que es el nombre en la definición
# #####-El argumento en este ejercicio corresponde a 5 ya que es el valor en la llamada

# %% [markdown]
# #### 10.   Argumentos por posición
#
# ##### *Complete la llamada para que se imprima: Ana 20 Bogota*

# %%
def perfil(nombre,edad,ciudad):
  print(nombre,edad,ciudad)

perfil("Ana","20","Bogotá")
# Out:
# Ana 20 Bogotá

# %% [markdown]
# #### 11.   Argumentos por nombre
#
# ##### *Complete los nombres de los parámetros para que el orden deje de importar.*

# %%
def perfil(nombre,edad,ciudad):
  print(nombre,edad,ciudad)

perfil(edad=20,nombre="Ana",ciudad="Bogotá")
# Out:
# Ana 20 Bogotá

# %% [markdown]
# #### 12.   Valor por defecto
#
# ##### *Complete el valor por defecto del parámetro saludo.*

# %%
def saludar(nombre, saludo="Hola"):
  print(saludo, nombre)

saludar("Ana")
# Out:
# Hola Ana

# %% [markdown]
# ##**C. Return y ámbito**

# %% [markdown]
# #### 13.   Devolver un valor
#
# ##### *Complete la palabra clave que entrega el resultado.*

# %%
def doble(n):
  return n*2

print(doble(5))
# Out:
# 10

# %% [markdown]
# #### 14.   Usar el valor devuelto
#
# ##### *Complete la llamada para guardar el resultado y operar con él.*

# %%
def doble(n):
  return n*2

resultado=doble(6)
print(resultado+1)
# Out:
# 13

# %% [markdown]
# #### 15.   Función sin return
#
# ##### *Sin ejecutar, determine qué imprimen las dos últimas líneas.*

# %%
def saludo(nombre):
  print("Hola,", nombre)

x=saludo("Ana")
print(x)
# Out:
# Hola, Ana
# None

# %% [markdown]
# #### **Respuesta:**
# #####-Arroja None por que no tenemos una función return que nos muestre el resultado de print (x)

# %% [markdown]
# #### 16.   print o return
#
# ##### *La suma falla porque la función no devuelve nada. Escriba la versión corregida de la función.*

# %%
def doble(n):
  return(n * 2)

total= doble(5)+ 3
print(total)
# Out:
# 13

# %% [markdown]
# #### 17.    return dentro de una condición
#
# ##### *Complete la instrucción que devuelve el segundo resultado.*

# %%
def signo(n):
  if n < 0:
    return "negativo"
  return "positivo"

print(signo(-4))
print(signo(7))
# Out:
# negativo
# positivo

# %% [markdown]
# #### 18.   Función que recibe una lista
#
# ##### *Complete la función que calcula el promedio de una lista de notas.*

# %%
def promedio(notas):
  total=0
  for n in notas:
    total= total + n
  return total/ len(notas)

print(promedio ([3.5,4.2,2.8]))
# Out:
# 3.5

# %% [markdown]
# #### 19.   Variable local y global
#
# ##### *Sin ejecutar, determine qué imprime cada una de las dos últimas líneas.*

# %%
mensaje = "Goblal"

def prueba():
  mensaje="Local"
  print(mensaje)

prueba()
print(mensaje)
# Out:
# Local
# Goblal

# %% [markdown]
# ##**Reto integrador**

# %% [markdown]
# #### 20. Reporte de notas con funciones
#
# ##### *Complete el programa que calcula el promedio de un estudiante y muestra si aprueba,usando dos funciones.*

# %%
def promedio(notas):
  total=0
  for n in notas:
    total= total + n
  return total/len(notas)

def reporte(nombre,notas):
  prom= promedio(notas)
  print(nombre,round(prom,2))
  if prom >= 3.0:
    print("Aprobado")
  else:
    print("No aprobado")

reporte("Laura",[3.5,4.2,2.8])
# Out:
# Laura 3.5
# Aprobado
