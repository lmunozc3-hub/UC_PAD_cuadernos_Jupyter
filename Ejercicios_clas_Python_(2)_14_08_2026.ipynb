# %% [markdown]
# #**Ejercicios de práctica Fundamentos Python (2)**
# ###Ejercicios de práctica listas, tuplas, diccionarios

# %% [markdown]
# ##**A-Listas**
# ####**Crear, recorrer, filtrar y acumular**

# %% [markdown]
# #### 1. Crear una lista de notas
#
# ##### *Complete la lista con cinco notas y muestre la cantidad de elementos.*

# %%
notas= [3.8,3.5,4.5,4.0,2.9]

print(len(notas))
print (notas)
# Out:
# 5
# [3.8, 3.5, 4.5, 4.0, 2.9]

# %% [markdown]
# #### 2. Acceder por índice
#
# ##### *Use índices para imprimir la primera, la tercera y la última temperatura*

# %%
temperaturas= [18,20,19,21,22]
print(temperaturas[0])
print(temperaturas[2])
print(temperaturas[-1])
# Out:
# 18
# 19
# 22

# %% [markdown]
# #### 3. Actualizar un elemento
#
# ##### *Corrija la segunda venta, que fue registrada como 80 pero debía ser 85.*

# %%
ventas = [120,80,200,50]

ventas [1]= 85
print (ventas)
# Out:
# [120, 85, 200, 50]

# %% [markdown]
# #### 4. Agregar y extraer datos
#
# ##### *Agregue una nueva nota y extraiga la última nota registrada*

# %%
notas = [3.5,4.0,2.8]

notas.append (4.6)
ultima = notas.pop ()

print(ultima)
print(notas)
# Out:
# 4.6
# [3.5, 4.0, 2.8]

# %% [markdown]
# #### 5. Calcular promedio
#
# ##### *Complete el acumulador para calcular el promedio de una lista*

# %%
notas=[4.2,3.8,5.0,2.9]
total= 0

for nota in notas:
  total= total + nota

promedio = total / len(notas)
print(round(promedio,2))
# Out:
# 3.98

# %% [markdown]
# #### 6.  Contar aprobados
#
# ##### *Cuente cuántas notas son mayores o iguales a 3.0*

# %%
notas= [4.2, 2.5, 3.0, 1.8, 4.7]
aprobados = 0

for nota in notas:
  if nota >= 3.0:
    aprobados = aprobados + 1
print (aprobados)
# Out:
# 3

# %% [markdown]
# #### 7.  Filtrar valores válidos
#
# ##### *Construya una lista con las temperaturas que estén entre -10 y 50 grados.*

# %%
lecturas = [18, 200, 21, -99, 19, 22]
validas = []

for t in lecturas:
  if t >= -10 and t <= 50:
    validas.append (t)

print (validas)
# Out:
# [18, 21, 19, 22]

# %% [markdown]
# #### 8.  Ordenar sin perder el original
#
# ##### *Use sorted() para crear una lista ordenada sin modificar la lista inicial.*

# %%
montos = [120000, 85000, 210000, 50000]

ordenados = sorted (montos)

print (montos)
print (ordenados)
# Out:
# [120000, 85000, 210000, 50000]
# [50000, 85000, 120000, 210000]

# %% [markdown]
# #### 9.  Comprensión de listas
#
# ##### *Complete la comprensión para obtener los cuadrados de los números pares*

# %%
numeros = [1, 2, 3, 4, 5, 6]

cuadrados_pares = [n**2 for n in numeros if n % 2==0]
print (cuadrados_pares)
# Out:
# [4, 16, 36]

# %% [markdown]
# #### 10.   Lista anidada
#
# ##### *Complete el doble ciclo para sumar todos los elementos de una matriz.*

# %%
matriz = [[1,2,3], [4,5,6]]
total = 0

for fila in matriz:
  for valor in fila :
    total= total + valor

print (total)
# Out:
# 21

# %% [markdown]
# ##**B. Tuplas**
# ####**Datos fijos, desempaquetado y uso como clave**

# %% [markdown]
# #### 11. Crear una tupla fija
#
# ##### *Defina una tupla con la latitud y la longitud de una sede*

# %%
ubicación = (4.60636, -74.06919)
print (ubicación)
print (type (ubicación))
# Out:
# (4.60636, -74.06919)
# <class 'tuple'>

# %% [markdown]
# #### 12.  Desempaquetar una tupla
#
# ##### *Asigne los elementos de la tupla a variables con nombres significativos*

# %%
registro = ("A01", "Laura", 4.6)
ID, nombre,nota = registro

print (nombre)
print (nota)
# Out:
# Laura
# 4.6

# %% [markdown]
# #### 13.  Tupla de un solo elemento
#
# ##### *Complete la sintaxis correcta de una tupla que contiene un solo código.*

# %%
codigo = ("A01")

print (codigo)
print (type (codigo))
# Out:
# A01
# <class 'str'>

# %% [markdown]
# #### 14.  Convertir lista a tupla
#
# ##### *Convierta una lista de columnas a tupla para evitar cambios accidentales*

# %%
columnas = ["fecha", "monto", "cliente"]

columnas_fijas = tuple (columnas)
print (columnas_fijas)
# Out:
# ('fecha', 'monto', 'cliente')

# %% [markdown]
# #### 15.   Retorno múltiple
#
# ##### *Complete una función que retorne el mínimo y el máximo como una tupla implícita.*

# %%
def resumen(valores):
  menor= min(valores)
  mayor= max(valores)
  return (menor,mayor)

minimo, maximo = resumen([8, 3 , 10, 5])
print(minimo,maximo)
# Out:
# 3 10

# %% [markdown]
# #### 16.   Recorrer inmutabilidad
#
# ##### *Ejecute mentalmente el código y explique qué error se produce.*

# %%
punto = (10,20)

punto[0] =99
print (punto)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_556/2354498151.py in <cell line: 0>()
#       1 punto = (10,20)
#       2
# ----> 3 punto[0] =99
#       4 print (punto)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #####**Respuesta**: Hay valores que no deben ser cambiado debido a que pueden ser codiciones de negocio inamobibles , entonces esto puede evitar que sean modificadas por error.

# %% [markdown]
# #### 17.   Tupla como clave
#
# ##### *Use una tupla como clave para almacenar una lectura por coordenada.*

# %%
lecturas = {}
coordenada = (4.65, -74.05)

lecturas[coordenada]=18.5
print(lecturas[4.65,-74.05])
# Out:
# 18.5

# %% [markdown]
# #### 18.   Combinar listas con zip
#
# ##### *Cree pares estudiante-nota usando zip() y conviértalos a lista* texto en negrita

# %%
nombres = ["Ana", "Luis", "Marta"]
notas = [4.2,3.8,5.0]

pares=list( zip (nombres, notas))
print (pares)
# Out:
# [('Ana', 4.2), ('Luis', 3.8), ('Marta', 5.0)]

# %% [markdown]
# ##**C. Diccionarios**
# ####**Pares clave-valor, acumuladores y registros**

# %% [markdown]
# #### 19.   Crear un diccionario
#
# ##### *Complete las claves necesarias para representar a un estudiante.*

# %%
estudiante = {
    "ID" : "A01",
    "Nombre": "Laura",
    "Nota" : 4.6
}

print(estudiante)
# Out:
# {'ID': 'A01', 'Nombre': 'Laura', 'Nota': 4.6}

# %% [markdown]
# #### 20.   Acceso seguro con get()
#
# ##### *Use get() para consultar una clave que podría no existir.*

# %%
cliente = {"nombre":"Carlos","puntaje": 720}

saldo= cliente.get("saldo",0)
print(saldo)
# Out:
# 0

# %% [markdown]
# #### 21.    Actualizar valores
#
# ##### *Actualice el stock de un producto después de una venta de 3 unidades.*

# %%
producto = {"codigo":"PO1","stock":8}

producto["stock"] = producto ["stock"] - 3
print(producto["stock"])
# Out:
# 5

# %% [markdown]
# #### 22.    Recorrer pares clave-valor
#
# ##### *Complete el recorrido para imprimir cada atributo con su valor.*

# %%
producto= {"codigo":"PO1","precio": 12000 ,"stock":8}

for clave,valor in producto.items():
  print(clave,valor)
# Out:
# codigo PO1
# precio 12000
# stock 8

# %% [markdown]
# #### 23.     Contar por categoría
# ##### *Use un diccionario acumulador para contar los tipos de transacción.*

# %%
tipos = ["debito", "credito", "debito", "debito", "credito"]
conteo= {}

for tipo in tipos:
  conteo[tipo]= conteo.get(tipo, 0) + 1

print(conteo)
# Out:
# {'debito': 3, 'credito': 2}

# %% [markdown]
# #### 24.     Diccionario anidado
# ##### *Acceda a la nota de Laura dentro de una estructura anidada*

# %%
grupo = {
    "A01":{"nombre":"Laura","Nota": 4.6},
    "A02":{"nombre":"Luis","Nota":3.8}
}

print(grupo["A01"]["Nota"])
# Out:
# 4.6

# %% [markdown]
# #### 25.   Lista de diccionarios
# ##### *Calcule el total de los montos en una lista de transacciones.*

# %%
transacciones=[
    {"ID":"T01","Monto":120000},
    {"ID":"T02","Monto":85000},
    {"ID":"T02","Monto":210000}
]

total=0

for t in transacciones:
  total= t["Monto"] + total

print(total)
# Out:
# 415000

# %% [markdown]
# #### 26.   Buscar por código
# ##### *Complete una búsqueda lineal sobre una lista de diccionarios.*

# %%
estudiantes = [
    {"codigo":"A01","nombre":"Laura"},
    {"codigo":"A02","nombre":"Luis"}
]

buscado= "A01"
resultado= None

for e in estudiantes:
  if e["codigo"] == buscado:
    resultado = e["nombre"]

print(resultado)
# Out:
# Laura

# %% [markdown]
# #### 27.   Buscar por código
# ##### *Construya una lista con los nombres de los estudiantes aprobados.*

# %%
estudiantes = [
    {"nombre":"Ana", "nota": 4.2},
    {"nombre":"Luis","nota": 2.8 },
    {"nombre":"Marta","nota":3.5 }
]

aprobados = []

for e in estudiantes:
  if e["nota"] > 3.0:
    aprobados.append(e["nombre"])

print(aprobados)
# Out:
# ['Ana', 'Marta']

# %% [markdown]
# #### 28.  Agrupar por estado
# ##### *Agrupe los nombres de los clientes según su nivel de riesgo.*

# %%
clientes = [
    {"nombre":"Ana", "riesgo": "bajo"},
    {"nombre":"Luis","riesgo": "alto" },
    {"nombre":"Marta","riesgo": "bajo" }
]

grupo = {}

for c in clientes:
  riesgo = c["riesgo"]
  if riesgo not in grupo:
    grupo[riesgo]=[]
  grupo[riesgo].append(c["nombre"])

print(grupo)
# Out:
# {'bajo': ['Ana', 'Marta'], 'alto': ['Luis']}

# %% [markdown]
# #### 29.  Inventario académico
# ##### *Complete el reporte de los productos con stock bajo.*

# %%
inventario = [
    {"producto":"Marcador", "stock": 4},
    {"producto":"Cuaderno", "stock": 20},
    {"producto":"Borrador", "stock": 2},
]

bajos= []

for item in inventario:
  if item["stock"] < 10:
    bajos.append(item["producto"])

print(bajos)
# Out:
# ['Marcador', 'Borrador']

# %% [markdown]
# ##**Reto integrador**
# ####**Combina listas de diccionarios, filtros y acumuladores**

# %% [markdown]
# #### 30.  Mini caso integrador
# ##### *Complete el algoritmo que calcula el total de los créditos mayores o iguales a 100000 y registra los clientes correspondientes.*

# %%
transacciones=[
    {"cliente":"Ana", "tipo": "Credito", "Monto": 120000},
    {"cliente":"Luis", "tipo": "Debito", "Monto": 85000},
    {"cliente":"Marta", "tipo": "Credito", "Monto": 210000}
]

total_creditos = 0
clientes = []

for t in transacciones:
  if t["tipo"] == "Credito" and t["Monto"] >= 100000:
    total_creditos = t["Monto"] + total_creditos
    clientes.append (t["cliente"])

print(total_creditos)
print(clientes)
# Out:
# 330000
# ['Ana', 'Marta']
