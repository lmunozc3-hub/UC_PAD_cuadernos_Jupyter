# %% [markdown]
# #**Ejercicios práctica estructuras de control y repetitivas**
# ###Ejercicios de práctica-Fundamentos Python (1)
# ####*Paradigmas de programación y estructuras de control*

# %% [markdown]
# ##**A-De la lógica a la decisión**

# %% [markdown]
# #### 1. Completa una decisión simple
#
# ##### *Completa la condición para mostrar “Mayor de edad” cuando la variable edad sea mayor o igual a 18.*

# %%
edad = 20
if edad > 18:
  print("Mayor de edad")
# Out:
# Mayor de edad

# %% [markdown]
# #### 2. Agrega la ruta alternativa
#
# ##### *Completa la estructura para clasificar una temperatura como “Alta” si supera 30 grados y “Normal” en caso contrario.*

# %%
temperatura = 32

if temperatura > 30:
  print("Alta")
else:
  print("Normal")
# Out:
# Alta

# %% [markdown]
# #### 3.  Predice la salida
#
# ##### *Sin ejecutar, escribe exactamente qué imprimirá el programa*

# %%
numero = 7

if numero %  2==0:
  print("Par")
else:
  print("Impar")
# Out:
# Impar

# %% [markdown]
# ##**B. Múltiples condiciones**

# %% [markdown]
# #### 4.  Completa la clasificación
#
# ##### *Agrega las dos expresiones faltantes para clasificar la nota.*

# %%
nota = 4.2

if nota >= 4.5:
  print("Excelente")
elif nota >= 4.0:
  print("Muy buen desempeño")
elif nota >= 3.0:
  print("Aprobado")
else:
  print("No aprobado")
# Out:
# Muy buen desempeño

# %% [markdown]
# #### 5. Corrige el orden
#
# ##### *El programa pretende mostrar “Excelente” para notas de 4.5 o más. Reescribe únicamente el bloque condicional en el orden correcto.*

# %%
nota = 4.8
if nota >= 4.5:
  print("Excelente")
elif nota >= 3.0:
  print("Aprobado")
# Out:
# Excelente

# %% [markdown]
# #### 6. Traza la ejecución
#
# ##### *Escribe la salida para valor = 12. Después indica cuál condición fue la primera verdadera.*

# %%
valor = 12

if valor < 5:
 print("A")
elif valor < 10:
 print("B")
elif valor < 15:
 print("C")
else:
 print("D")
# Out:
# C

# %% [markdown]
# ##**C. Operadores lógicos**

# %% [markdown]
# #### 7. Acceso con dos requisitos
#
# ##### *Completa el operador lógico para permitir acceso solo cuando ambas variables sean verdaderas*

# %%
usuario_activo = True
tiene_permiso = True

if usuario_activo and tiene_permiso:
  print("Acceso permitido")
else:
  print("Acceso denegado")
# Out:
# Acceso permitido

# %% [markdown]
# #### 8. Dos rutas válidas
#
# ##### *Completa la condición: se permite continuar si existe correo válido o teléfono válido.*

# %%
correo_valido = False
telefono_valido = True

if correo_valido or telefono_valido:
  print("Continuar registro")
else:
  print("Faltan datos de contacto")
# Out:
# Continuar registro

# %% [markdown]
# #### 9. Usa negación
#
# ##### *Completa la condición usando not para mostrar el mensaje solo si la cuenta NO está bloqueada.*

# %%
cuenta_bloqueada = False

if not cuenta_bloqueada:
  print("Puede operar")
# Out:
# Puede operar

# %% [markdown]
# ##**D. Estructura repetitiva for**

# %% [markdown]
# #### 10. Recorre del 1 al 5
#
# ##### *Completa range() para imprimir los valores 1, 2, 3, 4 y 5.*

# %%
for numero in range(1,6):
  print(numero)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# #### 11. Recorre con paso
#
# ##### *Completa range() para imprimir 2, 4, 6, 8 y 10.*

# %%
for numero in range(2,11,2):
 print(numero)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# #### 12. Predice el acumulado
#
# ##### *Sin ejecutar, determina el valor final de suma.*

# %%
suma = 0

for i in range(1,4):
  suma= suma + i
print(suma)
# Out:
# 6

# %% [markdown]
# ##**E. Estructura repetitiva while**

# %% [markdown]
# #### 13. Completa el contador
#
# ##### *Completa la condición y la actualización para imprimir los números del 1 al 5.*

# %%
numero = 1

while numero <= 5:
  print(numero)
  numero = numero + 1

# %% [markdown]
# #### 14. Encuentra el ciclo infinito
#
# ##### *El siguiente programa nunca termina. Corrige solo la línea que falta dentro del ciclo.*

# %%
numero = 1

while numero <= 5:
  print(numero)
  numero = numero + 2
# Out:
# 1
# 3
# 5

# %% [markdown]
# #### 15. Control de intentos
#
# ##### *Completa el ciclo para permitir máximo 3 intentos. No modifiques las líneas ya escritas.*

# %%
intentos = 0

while intentos <= 2:
  clave = input("Ingrese clave: ")
  intentos = intentos + 1

print("Proceso finalizado")
# Out:
# Ingrese clave: 3
# Ingrese clave: 3
# Ingrese clave: 3
# Proceso finalizado

# %% [markdown]
# ##**F. Elegir y combinar estructuras**

# %% [markdown]
# #### 16. ¿for o while?
#
# ##### *Escribe la estructura que elegirías en cada situación.*

# %% [markdown]
# ######Procesar exactamente 10 mediciones----------------------------> for
# ######Pedir una clave hasta que sea correcta------------------------> While
# ######Imprimir los números del 1 al 20------------------------------> for
# ######Repetir un cálculo hasta que el error sea menor que 0.01------> While

# %% [markdown]
# #### 17. Combina for + if
#
# ##### *Completa el programa para recorrer del 1 al 12 y mostrar únicamente los múltiplos de 3.*

# %%
for numero in range(1,13):
    if numero % 3 == 0:
       print(numero)
# Out:
# 3
# 6
# 9
# 12

# %% [markdown]
# #### 18. Predice antes de ejecutar
#
# ##### *Escribe todas las líneas que producirá el programa*

# %%
for numero in range(1,8):
  if numero  < 3:
    print(numero,"A")
  elif numero  < 6:
    print(numero,"B")
  else:
    print(numero,"C")
# Out:
# 1 A
# 2 A
# 3 B
# 4 B
# 5 B
# 6 C
# 7 C

# %% [markdown]
# ##**G. Del pseudocódigo a Python**

# %% [markdown]
# #### 19. Traduce una decisión
#
# ##### *Completa el código Python para que represente exactamente el pseudocódigo mostrado*

# %%
nota = float(input("Nota: "))

if nota >= 3.0:
  print("Aprobado")
else:
  print("No aprobado")
# Out:
# Nota: 2
# No aprobado

# %% [markdown]
# #### 20. Traduce una repetición
#
# ##### *Completa el programa Python equivalente al pseudocódigo.*

# %%
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ##**RETO INTEGRADOR**

# %% [markdown]
# #### R. Clasificación de temperaturas
#
# ##### *Completa todos los espacios. Antes de ejecutar, prueba mentalmente tu solución con los valores: 15, 18, 22, 25 y 30.*

# %%
for t in range (1,6):
  t= float(input("Temperatura: "))

  if t < 18:
    print("Baja")
  elif t <= 25:
    print("Normal")
  else:
    print("Alta")
# Out:
# Temperatura: 15
# Baja
# Temperatura: 18
# Normal
# Temperatura: 22
# Normal
# Temperatura: 25
# Normal
# Temperatura: 30
# Alta
